# %%
import numpy as np
from scipy.stats import norm

# %%
sample = [172, 174, 168, 171, 173, 175, 170, 169, 172, 190, 123, 111, 187, 211 , 99, 10, 21,29,32,43,56]
population_mean = 170
population_std = 3
samp_mean = np.mean(sample)
n = len(sample)

# %%
z_score = (samp_mean - population_mean) / (population_std / np.sqrt(n))
z_score
# Out:
# np.float64(-66.48371722523233)

# %%
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# %%
p_value
# Out:
# np.float64(0.0)

# %%
alpha = 0.05

if p_value < alpha:
    print("I will reject the null hypothesis")
else:
    print("I will accept the null hypothesis")
# Out:
# I will reject the null hypothesis
